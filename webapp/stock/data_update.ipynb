# %%
import pandas as pd
from datetime import datetime, timedelta
from pytz import timezone
from pykrx import stock
import glob, os

# %%
time_now = datetime.now(tz=timezone('Asia/Seoul'))
time_now_str = time_now.strftime(format='%Y%m%d')
# ticker_list = stock.get_market_ticker_list(date=time_now, market='KOSPI')
time_start = time_now - timedelta(days=365*5)       #5년전부터 가져오기
time_start_str = time_start.strftime(format='%Y%m%d')

data_dir = os.path.join("..", 'media')

print("time now : ", time_now_str)
print("time start : ", time_start_str)
# Out:
# time now :  20220607
# time start :  20170608

# %% [markdown]
# # 전체 주식 시가총액 불러오기

# %%
stock.get_market_cap(date=time_now_str, prev=True,  market='KOSPI')
# Out:
#             종가             시가총액       거래량           거래대금       상장주식수
# 티커
# 005930   65500  391020757025000  19306032  1270180488500  5969782550
# 373220  432000  101088000000000    179698    78210475000   234000000
# 000660  104000   75712245960000   3160920   330988776000   728002365
# 207940  822000   58505028000000     71239    58862752000    71174000
# 005935   59500   48961758650000   1042033    62296155757   822886700
# ...        ...              ...       ...            ...         ...
# 002787   16500       4864332000       148        2425250      294808
# 001525    7800       4818301800      5585       44153820      617731
# 000547   27300       4193280000       282        7601550      153600
# 001529   27250       2444924500     24735      700629200       89722
# 009275   24700       2241278000      8382      214143700       90740
#
# [941 rows x 5 columns]

# %%
market_cap = stock.get_market_cap(date=time_now_str, prev=True,  market='KOSPI')  #시가총액 순으로 정렬된 dataframe 반환
market_cap['종목이름'] = [stock.get_market_ticker_name(tk) for tk in market_cap.index]
market_cap = market_cap[:50]

# %%
market_cap
# Out:
#             종가             시가총액       거래량           거래대금       상장주식수  \
# 티커
# 005930   65500  391020757025000  19306032  1270180488500  5969782550
# 373220  432000  101088000000000    179698    78210475000   234000000
# 000660  104000   75712245960000   3160920   330988776000   728002365
# 207940  822000   58505028000000     71239    58862752000    71174000
# 005935   59500   48961758650000   1042033    62296155757   822886700
# 035420  278000   45605645630000    658396   183767969000   164049085
# 051910  556000   39249342708000    308321   173649396000    70592343
# 005380  183500   39208112314500    619948   114424819500   213668187
# 006400  536000   36857788080000    490598   267699057000    68764530
# 035720   81900   36370818829800   2365939   195512960300   444088142
# 000270   83000   33645157801000    871124    72325830000   405363347
# 005490  287000   25022621645000    240589    69550325500    87186835
# ...

# %% [markdown]
# # ticker로 5년간 데이터 불러오기

# %%
for ticker in market_cap.index:
    
    ticker_name = stock.get_market_ticker_name(ticker)
    # ticker_name = market_cap.loc[ticker, '종목이름']
    # ticker_dir = os.path.join(data_dir , f"{ticker}")
    print(ticker, ticker_name)
    # try:                                        #회사 폴더 없으면 생성
    #     os.mkdir(ticker_dir)       
    # except:                                     #있으면 말고
    #     pass

    # data = stock.get_market_ohlcv_by_date(fromdate=time_start_str, todate=time_now_str, ticker=ticker)
    # data.to_csv(f"{ticker_dir}/{ticker}.csv", encoding='cp949')
# Out:
# 005930 삼성전자
# 373220 LG에너지솔루션
# 000660 SK하이닉스
# 207940 삼성바이오로직스
# 005935 삼성전자우
# 035420 NAVER
# 051910 LG화학
# 005380 현대차
# 006400 삼성SDI
# 035720 카카오
# 000270 기아
# 005490 POSCO홀딩스
# 105560 KB금융
# 068270 셀트리온
# 096770 SK이노베이션
# 028260 삼성물산
# 055550 신한지주
# 012330 현대모비스
# 323410 카카오뱅크
# 034730 SK
# 066570 LG전자
# 011200 HMM
# 015760 한국전력
# 377300 카카오페이
# 086790 하나금융지주
# 010950 S-Oil
# 259960 크래프톤
# 032830 삼성생명
# 003550 LG
# 034020 두산에너빌리티
# 017670 SK텔레콤
# 033780 KT&G
# 329180 현대중공업
# 018260 삼성에스디에스
# 051900 LG생활건강
# 010130 고려아연
# 009150 삼성전기
# 316140 우리금융지주
# 003490 대한항공
# 003670 포스코케미칼
# 030200 KT
# 036570 엔씨소프트
# 302440 SK바이오사이언스
# 090430 아모레퍼시픽
# 000810 삼성화재
# 011070 LG이노텍
# 352820 하이브
# 361610 SK아이이테크놀로지
# 024110 기업은행
# 009830 한화솔루션

# %%
# allstocks = pd.read_csv(os.path.join(os.getcwd(), "webapp", "media", "상장법인목록.csv"), encoding='cp949')
allstocks = pd.read_csv(os.path.join("..", "media", "상장법인목록.csv"), encoding='cp949', index_col=0)

# %%
[(idx, idx) for idx in allstocks.index]
# Out:
# [('LG에너지솔루션', 'LG에너지솔루션'),
#  ('SK스퀘어', 'SK스퀘어'),
#  ('카카오페이', '카카오페이'),
#  ('현대중공업', '현대중공업'),
#  ('크래프톤', '크래프톤'),
#  ('PI첨단소재', 'PI첨단소재'),
#  ('카카오뱅크', '카카오뱅크'),
#  ('SK아이이테크놀로지', 'SK아이이테크놀로지'),
#  ('SK바이오사이언스', 'SK바이오사이언스'),
#  ('DL이앤씨', 'DL이앤씨'),
#  ('명신산업', '명신산업'),
#  ('하이브', '하이브'),
#  ('에스케이바이오팜', '에스케이바이오팜'),
#  ('한화시스템', '한화시스템'),
#  ('지누스', '지누스'),
#  ('두산퓨얼셀', '두산퓨얼셀'),
#  ('포스코케미칼', '포스코케미칼'),
#  ('더블유게임즈', '더블유게임즈'),
#  ('우리금융지주', '우리금융지주'),
#  ('효성첨단소재', '효성첨단소재'),
#  ('효성티앤씨', '효성티앤씨'),
#  ('HDC현대산업개발', 'HDC현대산업개발'),
#  ('셀트리온', '셀트리온'),
#  ('쿠쿠홈시스', '쿠쿠홈시스'),
#  ('SK케미칼', 'SK케미칼'),
#  ('BGF리테일', 'BGF리테일'),
#  ('카카오', '카카오'),
#  ('오리온', '오리온'),
#  ('넷마블', '넷마블'),
#  ('HD현대', 'HD현대'),
#  ('두산밥캣', '두산밥캣'),
#  ('삼성바이오로직스', '삼성바이오로직스'),
#  ('화승엔터프라이즈', '화승엔터프라이즈'),
#  ('동서', '동서'),
#  ('LIG넥스원', 'LIG넥스원'),
#  ('삼성물산', '삼성물산'),
#  ('씨에스윈드', '씨에스윈드'),
#  ('삼성에스디에스', '삼성에스디에스'),
#  ('만도', '만도'),
#  ('쿠쿠홀딩스', '쿠쿠홀딩스'),
#  ('코스맥스', '코스맥스'),
#  ('종근당', '종근당'),
# ...

# %%
pd.concat([allstocks.index.to_series(), allstocks.index.to_series()], axis=1)
# Out:
#                회사명       회사명
# 회사명
# LG에너지솔루션  LG에너지솔루션  LG에너지솔루션
# SK스퀘어        SK스퀘어     SK스퀘어
# 카카오페이        카카오페이     카카오페이
# 현대중공업        현대중공업     현대중공업
# 크래프톤          크래프톤      크래프톤
# ...            ...       ...
# 삼양홀딩스        삼양홀딩스     삼양홀딩스
# 한국앤컴퍼니      한국앤컴퍼니    한국앤컴퍼니
# 대한항공          대한항공      대한항공
# 유한양행          유한양행      유한양행
# CJ대한통운      CJ대한통운    CJ대한통운
#
# [200 rows x 2 columns]

# %%
import pandas as pd
allstocks = pd.read_csv(os.path.join("..", "media", "상장법인목록.csv"), encoding='cp949', index_col=0)

# %%
showstock = allstocks.loc['LG']

# %%
showstock.loc['종목코드'] = format(showstock['종목코드'].copy(), '06')
# Out:
# C:\Users\DJK-Office\AppData\Local\Temp\ipykernel_27948\1603536188.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   showstock.loc['종목코드'] = format(showstock['종목코드'].copy(), '06')

# %%
showstock
# Out:
# 종목코드                 003550
# 업종                   기타 금융업
# 주요제품                   지주회사
# 상장일              1970-02-13
# 결산월                     12월
# 대표자명               구광모, 권봉석
# 홈페이지    http://www.lg.co.kr
# 지역                    서울특별시
# Name: LG, dtype: object

# %%
for i in showstock:
    print(format(i, '06'))
# Out:
# 003550
# 기타 금융업
# 지주회사00
# 1970-02-13
# 12월000
# 구광모, 권봉석
# http://www.lg.co.kr
# 서울특별시0

# %%
import pandas as pd
showstock = allstocks = pd.read_csv(os.path.join("..", "media", "상장법인목록.csv"), encoding='cp949', index_col=1)
showstock.index = [format(code, '06') for code in showstock.index]

# %%
showstock
# Out:
#              회사명              업종  \
# 373220  LG에너지솔루션  일차전지 및 축전지 제조업
# 402340     SK스퀘어          기타 금융업
# 377300     카카오페이      금융 지원 서비스업
# 329180     현대중공업     선박 및 보트 건조업
# 259960      크래프톤  소프트웨어 개발 및 공급업
# ...          ...             ...
# 000070     삼양홀딩스          기타 금융업
# 000240    한국앤컴퍼니          기타 금융업
# 003490      대한항공       항공 여객 운송업
# 000100      유한양행         의약품 제조업
# 000120    CJ대한통운       도로 화물 운송업
#
#                                                      주요제품         상장일  결산월  \
# 373220                                2차전지 (소형,ESS,자동차전지)  2022-01-27  12월
# 402340                                               지주회사  2021-11-29  12월
# 377300                              간편결제, 간편송금 및 기타 금융서비스  2021-11-03  12월
# 329180                                 선박, 해양플랜트 및 엔진기계 등  2021-09-17  12월
# 259960                                         등 게임 소프트웨어  2021-08-10  12월
# ...                                                   ...         ...  ...
# ...
