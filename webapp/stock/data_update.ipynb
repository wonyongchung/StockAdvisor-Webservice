# %%
import pandas as pd
from datetime import datetime, timedelta
from pytz import timezone
from pykrx import stock
import glob, os

# %%
time_now = datetime.now(tz=timezone('Asia/Seoul'))
time_now_str = time_now.strftime(format='%Y%m%d')
# ticker_list = stock.get_market_ticker_list(date=time_now, market='KOSPI')
time_start = time_now - timedelta(days=365*5)       #5년전부터 가져오기
time_start_str = time_start.strftime(format='%Y%m%d')

data_dir = os.path.join("..", 'media')

print("time now : ", time_now_str)
print("time start : ", time_start_str)
# Out:
# time now :  20220602
# time start :  20170603

# %% [markdown]
# # 전체 주식 시가총액 불러오기

# %%
stock.get_market_cap(date=time_now_str, prev=True,  market='KOSPI')
# Out:
#             종가             시가총액       거래량           거래대금       상장주식수
# 티커
# 005930   67400  402363343870000  24365002  1637773742750  5969782550
# 373220  444000  103896000000000    345830   152722959500   234000000
# 000660  108000   78624255420000   4024509   431706106000   728002365
# 207940  847000   60284378000000     76864    64910615000    71174000
# 005935   60700   49949222690000   2118486   128713777900   822886700
# ...        ...              ...       ...            ...         ...
# 001525    8170       5046862270      1663       13522660      617731
# 002787   16400       4834851200      1243       20472350      294808
# 000547   28100       4316160000       222        6229700      153600
# 001529   37400       3355602800      6081      227528850       89722
# 009275   32000       2903680000      1498       47541850       90740
#
# [941 rows x 5 columns]

# %%
market_cap = stock.get_market_cap(date=time_now_str, prev=True,  market='KOSPI')  #시가총액 순으로 정렬된 dataframe 반환
market_cap['종목이름'] = [stock.get_market_ticker_name(tk) for tk in market_cap.index]
market_cap = market_cap[:50]

# %% [markdown]
# # ticker로 5년간 데이터 불러오기

# %%
for ticker in market_cap.index:
    
    # ticker_name = stock.get_market_ticker_name(ticker)
    ticker_name = market_cap.loc[ticker, '종목이름']
    ticker_dir = os.path.join(data_dir , f"{ticker_name}")
    try:                                        #회사 폴더 없으면 생성
        os.mkdir(ticker_dir)       
    except:                                     #있으면 말고
        pass

    data = stock.get_market_ohlcv_by_date(fromdate=time_start_str, todate=time_now_str, ticker=ticker)
    data.to_csv(f"{ticker_dir}/{ticker_name}.csv", encoding='cp949')
# Out:
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
# Directory Created
